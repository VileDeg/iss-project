# %%
# -------------- Cosinusovky a komplexni exponencialy  pro ISS --------------------------
import numpy as np
import matplotlib.pyplot as plt
# ---------------------- cos --------------------------------
t = np.arange(0, 2*np.pi, 0.05)
x = np.cos(t)
plt.figure(figsize=(8,4))
plt.plot(t,x) 
plt.gca().set_xticks([0, np.pi/2, np.pi, 3*np.pi/2, 2*np.pi])
plt.gca().set_xticklabels(['0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$'])
plt.gca().set_xlabel('$t$')
plt.gca().set_ylabel('$x(t)$')
plt.gca().grid()
plt.savefig('FIG/cos_basic.pdf')

# %%
# cosinusovky s frekvenci, amplitudou a poc. fazi - spojity cas 
t = np.arange(-5,15,0.05)
x1 = np.cos(2*np.pi*0.5*t)
x2 = 10*np.cos(2*np.pi*0.5*t)
x3 = 10*np.cos(2*np.pi*0.5*t+0.5*np.pi)
_, ax = plt.subplots(3,1, figsize=(10,5))
ax[0].plot(t,x1)
ax[0].set_title('$\cos(2 \pi 0.5 t)$')
ax[0].set_xticklabels([])
ax[0].grid()
ax[1].plot(t,x2)
ax[1].set_title('$10\cos(2 \pi 0.5 t)$')
ax[1].set_xticklabels([])
ax[1].grid()
ax[2].plot(t,x3)
ax[2].set_title('$10\cos(2 \pi 0.5 t+ \pi/2)$')
ax[2].grid()
plt.savefig('FIG/cos.pdf')

# %%
# to stejne pro diskretni cas 
N = 50 
n = np.arange(0,N)
x1 = np.cos(2*np.pi/N*n)
x2 = 10*np.cos(2*np.pi/N*n + np.pi/2)
x3 = np.cos(5*2*np.pi/N*n)
_, ax = plt.subplots(3,1, figsize=(10,5))
ax[0].stem(n,x1,basefmt=" ")  # nechci cervenou baseline ...
ax[0].set_title('$\cos(2 \pi n / N)$')
ax[0].set_xticklabels([])
ax[0].grid()
ax[1].stem(n,x2,basefmt=" ")  # nechci cervenou baseline ...
ax[1].set_title('$10\cos(2 \pi n / N + \pi  /2)$')
ax[1].set_xticklabels([])
ax[1].grid()
ax[2].stem(n,x3,basefmt=" ")  # nechci cervenou baseline ...
ax[2].set_title('$\cos(2 \pi 5 n / N)$')
ax[2].grid()
plt.savefig('FIG/diskcos.pdf')

# %%
# --------------- kokmplexni cisla - zaklady ---------------------
import matplotlib.patches as mpatches
z = -3 + 4j
r = np.abs(z)
phi = np.angle(z)
plt.figure(figsize=(3,3))
plt.gca().set_ylim(-5,5)
plt.gca().set_xlim(-5,5)
plt.gca().scatter(np.real(z),np.imag(z),color='r')
plt.gca().arrow(0, 0, np.real(z),np.imag(z), head_width=0.3, head_length=0.7, length_includes_head=True, fc='black', ec='black')
pac = mpatches.Arc([0, 0], r, r, angle=0, theta1=0, theta2=phi/np.pi*180, linestyle='--',color='r')
plt.gca().add_patch(pac)
plt.gca().grid()
plt.gca().set_xlabel('Real')
plt.gca().set_ylabel('Imag')
plt.savefig('FIG/z1.pdf')

# %%
z = -1/np.sqrt(2) + -1j/np.sqrt(2)
r = np.abs(z)
phi = np.angle(z)
plt.figure(figsize=(3,3))
plt.gca().set_ylim(-1,1)
plt.gca().set_xlim(-1,1)
plt.gca().scatter(np.real(z),np.imag(z),color='r')
plt.gca().arrow(0, 0, np.real(z),np.imag(z), head_width=0.3/4, head_length=0.7/4, length_includes_head=True, fc='black', ec='black')
pac = mpatches.Arc([0, 0], r, r, angle=0, theta1=0, theta2=phi/np.pi*180, linestyle='--',color='r')
plt.gca().add_patch(pac)
pac = mpatches.Arc([0, 0], 1.2*r, 1.2*r, angle=0, theta1=phi/np.pi*180, theta2 = 0, linestyle='--',color='b')
plt.gca().add_patch(pac)
plt.gca().grid()
plt.gca().set_xlabel('Real')
plt.gca().set_ylabel('Imag')
plt.savefig('FIG/z2.pdf')

# %%
z = 2 + 3j
zstar = np.conj(z)
auxx = np.real(z + zstar)
plt.figure(figsize=(3,3))
plt.gca().set_ylim(-3.5,3.5)
plt.gca().set_xlim(-0.5,5.5)
plt.gca().scatter(np.real(z),np.imag(z),color='r')
plt.gca().scatter(np.real(zstar),np.imag(zstar),color='b')
plt.gca().text(np.real(z)+0.3,np.imag(z),'$z$')
plt.gca().text(np.real(zstar)+0.3,np.imag(zstar),'$z^{\star}$')
plt.gca().text(auxx+0.1,0.1,'$z + z^{\star}$')
plt.gca().scatter(auxx,0,color='k')
plt.gca().arrow(0, 0, np.real(z),np.imag(z), head_width=0.1, head_length=0.3, length_includes_head=True, fc='black', ec='black')
plt.gca().arrow(0, 0, np.real(zstar),np.imag(zstar), head_width=0.1, head_length=0.3, length_includes_head=True, fc='black', ec='black')
plt.gca().arrow(np.real(zstar),np.imag(zstar),np.real(zstar),-np.imag(zstar),head_width=0.2,head_length=0.3,length_includes_head=True,linestyle="--", fc='black', ec='black')
plt.gca().arrow(0,0,auxx,0,head_width=0.1, head_length=0.3, linewidth=3, length_includes_head=True, fc='black', ec='black')
plt.gca().arrow(np.real(z),np.imag(z),np.real(z),-np.imag(z),head_width=0.2,head_length=0.3,length_includes_head=True,linestyle="--",fc='black',ec='black')
# prvni sipka do z + z* se stale kresli jako plna a ne jako carkovana, nevim, co z s tim :( 
plt.gca().grid()
plt.gca().set_xlabel('Real')
plt.gca().set_ylabel('Imag')
plt.savefig('FIG/komplex_sdruzeni.pdf')

# %%
# ---- jednotkova kruznice ----
plt.figure(figsize=(3,3))
plt.gca().set_ylim(-1.1,1.1)
plt.gca().set_xlim(-1.1,1.1)
pac = mpatches.Arc([0, 0], 2, 2, angle=0, theta1=0, theta2=360, linestyle='--',color='k')
plt.gca().add_patch(pac)
z = np.exp(1j*np.pi/5)
plt.gca().scatter(np.real(z),np.imag(z),color='r')
plt.gca().arrow(0, 0, np.real(z),np.imag(z), head_width=0.05, head_length=0.1, length_includes_head=True, fc='black', ec='black')
plt.gca().arrow(0,0,np.real(z),0,linewidth=3, fc='r', ec='r')
plt.gca().arrow(0,0,0,np.imag(z),linewidth=3, fc='b', ec='b')
plt.gca().text(np.real(z)+0.1,np.imag(z),'$z$')
plt.gca().text(np.real(z)/2,-0.15,'$\cos(\phi)$',color='r')
plt.gca().text(-0.5,np.imag(z)/2,'$\sin(\phi)$',color='b')
plt.gca().grid()
plt.gca().set_xlabel('Real')
plt.gca().set_ylabel('Imag')
plt.savefig('FIG/jednotkova_kruznice.pdf')

# %%
# vypocet cos pomoci souctu komp. sdruzenych cisel 
plt.figure(figsize=(3,3))
plt.gca().set_ylim(-1.1,1.1)
plt.gca().set_xlim(-1.1,1.1)
pac = mpatches.Arc([0, 0], 2, 2, angle=0, theta1=0, theta2=360, linestyle='--',color='k')
plt.gca().add_patch(pac)
z = np.exp(1j*np.pi/5)
zstar = np.exp(-1j*np.pi/5)
aux = np.real(z)
plt.gca().scatter(np.real(z),np.imag(z),color='r')
plt.gca().text(np.real(z),np.imag(z)+0.1,'$e^{j\phi}$')
plt.gca().scatter(np.real(zstar),np.imag(zstar),color='b')
plt.gca().text(np.real(zstar),np.imag(zstar)-0.2,'$e^{-j\phi}$')
plt.gca().scatter(aux,0,s=50,color='k',)
plt.gca().text(aux,-0.2,'$\cos(\phi)$',horizontalalignment='center')
plt.gca().scatter(2*aux,0,s=50,color='k',)
plt.gca().text(2*aux,-0.2,'$2\cos(\phi)$',horizontalalignment='center')
plt.gca().arrow(0, 0, np.real(z),np.imag(z), head_width=0.05, head_length=0.1, length_includes_head=True, fc='red', ec='red')
plt.gca().arrow(0, 0, np.real(zstar),np.imag(zstar), head_width=0.05, head_length=0.1, length_includes_head=True, fc='blue', ec='blue')
plt.gca().arrow(np.real(z),np.imag(z),np.real(z),-np.imag(z),linestyle="--",head_width=0.05, head_length=0.1, length_includes_head=True, fc='black', ec='black')
plt.gca().arrow(np.real(zstar),np.imag(zstar),np.real(zstar),-np.imag(zstar),linestyle="--",head_width=0.05, head_length=0.1, length_includes_head=True, fc='black', ec='black')
plt.gca().grid()
plt.gca().set_xlim(-0.05,2.05)
plt.gca().set_xlabel('Real')
plt.gca().set_ylabel('Imag')
plt.savefig('FIG/ejfi_eminusjfi.pdf')

# %%
# pohyb bodu po jednotkove kruznici
plt.figure(figsize=(4,3))
plt.gca().set_ylim(-1.1,1.1)
plt.gca().set_xlim(-1.1,1.2)
pac = mpatches.Arc([0, 0], 2, 2, angle=0, theta1=0, theta2=360, linestyle='--',color='k')
plt.gca().add_patch(pac)
phis = np.arange(0,2*np.pi,2*np.pi/8)
zs = np.exp(1j * phis)
plt.gca().scatter(np.real(zs),np.imag(zs),color='r')
texts = ['$e^{j0}$ = $e^{j2\pi} = 1$','$e^{j\pi/4}$','$e^{j\pi/2}$','$e^{j3\pi/4}$','$e^{j\pi}$','$e^{j5\pi/4}$','$e^{j3\pi/2}$','$e^{j7\pi/4}$']       
#plt.gca().text(np.real(zs),np.imag(zs),text)
for i, text in enumerate(texts):
  plt.gca().annotate(text, (np.real(zs[i])+0.1, np.imag(zs[i])))
plt.gca().grid()
plt.gca().set_xlabel('Real')
plt.gca().set_ylabel('Imag')
plt.tight_layout()
plt.savefig('FIG/ejx.pdf')

# %%
# ----- kompexni exponenciala ve 3d ... 
from mpl_toolkits import mplot3d

# funkce pro komplexni drateny barel 
def complex_cylinder(t1, t2, r, fig):
    '''kresli sedy drateny valec ve 3d tak, aby byla dobre videt komplexni exponenciala. 
    t1 je pocatecni cas
    t2 je koncovy cas 
    r je polomer
    fig je obrazek'''
    phi = np.linspace(0,2 * np.pi,100)
    t = np.linspace(t1,t2,9)
    kolo = r * np.exp(1j * phi)
    for tt in t: 
        fig.plot3D(tt * np.ones(phi.shape), np.real(kolo), np.imag(kolo),color='k',alpha=0.1)
    phi = np.linspace(0,2 * np.pi,32)
    kolo = r * np.exp(1j * phi)
    for z in kolo:        
        line=art3d.Line3D(*zip((t1,np.real(z),np.imag(z)), (t2,np.real(z),np.imag(z))), markevery=(1, 1), color='k',alpha=0.1)
        ax.add_line(line)   
        
t = np.arange(0,2*np.pi,0.05)
x = np.exp(1j*t)
plt.figure(figsize=(8,3))
ax = plt.axes(projection="3d")
ax.plot3D(t, np.real(x), np.imag(x))
ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
ax.set_zlabel('$imag(x(t))$')
complex_cylinder(0,2*np.pi,1,ax)

plt.savefig('FIG/kexp.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 32
#      30 ax.set_zticks([-1, 0, 1])
#      31 ax.set_zlabel('$imag(x(t))$')
# ---> 32 complex_cylinder(0,2*np.pi,1,ax)
#      34 plt.savefig('FIG/kexp.pdf')
#
# Cell In [14], line 19, in complex_cylinder(t1, t2, r, fig)
#      17 kolo = r * np.exp(1j * phi)
#      18 for z in kolo:
# ---> 19     line=art3d.Line3D(*zip((t1,np.real(z),np.imag(z)), (t2,np.real(z),np.imag(z))), markevery=(1, 1), color='k',alpha=0.1)
#      20     ax.add_line(line)
#
# NameError: name 'art3d' is not defined

# %%
# prumet do cos a do sin
# reseni pruhlednosti viz https://stackoverflow.com/questions/23403293/3d-surface-not-transparent-inspite-of-setting-alpha
plt.figure(figsize=(8,3))
ax = plt.axes(projection="3d")
verts = [list(zip(t,np.zeros(t.shape),np.imag(x)))]
sin2d = mplot3d.art3d.Poly3DCollection(verts, alpha=0.5, linewidth=1)
sin2d.set_facecolor((0, 0, 1, 0.2))   # 0.5 is alpha
ax.add_collection3d(sin2d)
# needs to do a little fix for cos - adding zero element at beg and end ...
aux1 = np.pad(t, (1,1), 'constant', constant_values=(0,np.max(t))) 
aux2 = np.pad(np.real(x), (1,1), 'constant', constant_values=(0,0))
aux3 = np.pad(np.zeros(t.shape), (1,1), 'constant', constant_values=(0,0))
verts = [list(zip(aux1,aux2,aux3))]
cos2d = mplot3d.art3d.Poly3DCollection(verts, alpha=0.5, linewidth=1)
sin2d.set_facecolor((1, 0, 0, 0.2))   # 0.5 is alpha
ax.add_collection3d(cos2d)

ax.plot3D(t, np.real(x), np.imag(x),linewidth=3)#,color='k')
ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
ax.set_zlabel('$imag(x(t))$')
complex_cylinder(0,2*np.pi,1,ax)

plt.savefig('FIG/cossin.pdf')

# %%
# plus a minus j 
t = np.arange(0,2*np.pi,0.05)
x = np.exp(1j*t)
plt.figure(figsize=(8,3))
ax = plt.axes(projection="3d")
ax.plot3D(t, np.real(x), np.imag(x),color='b',label='$e^{jt}$')
ax.plot3D(t, np.real(x), -np.imag(x),color='r',label='$e^{-jt}$')
ax.legend()
ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
ax.set_zlabel('$imag(x(t))$')
complex_cylinder(0,2*np.pi,1,ax)

plt.savefig('FIG/exp_plus_minus.pdf')

# %%
# zmena modulu 
t = np.arange(0,2*np.pi,0.05)
x = np.exp(1j*t)
bigx = 2*np.exp(1j*t)
smallx = 2/3*np.exp(1j*t)
plt.figure(figsize=(8,3))
ax = plt.axes(projection="3d")
ax.plot3D(t, np.real(x), np.imag(x),color='b',label='$e^{jt}$')
ax.plot3D(t, np.real(bigx), np.imag(bigx),color='r',label='$2e^{jt}$')
ax.plot3D(t, np.real(smallx), np.imag(smallx),color='g',label='$2/3e^{jt}$')
ax.legend()
ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_yticks([-2, 0, 2])
ax.set_zticks([-2, 0, 2])
ax.set_zlabel('$imag(x(t))$')
complex_cylinder(0,2*np.pi,1,ax)
complex_cylinder(0,2*np.pi,2,ax)
complex_cylinder(0,2*np.pi,2/3,ax)

plt.savefig('FIG/exp_zmena_modulu.pdf')

# %%
# zmena predtoceni 
t = np.arange(0,2*np.pi,0.05)
x = np.exp(1j*t)
x1 = np.exp(1j*np.pi/4)*np.exp(1j*t)
x2 = np.exp(-1j*2*np.pi/3)*np.exp(1j*t)
plt.figure(figsize=(8,3))
ax = plt.axes(projection="3d")
ax.plot3D(t, np.real(x), np.imag(x),color='b',label='$e^{jt}$')
ax.plot3D(t, np.real(x1), np.imag(x1),color='r',label='$e^{j\pi/4}e^{jt}$')
ax.plot3D(t, np.real(x2), np.imag(x2),color='g',label='$e^{-j2\pi/3}e^{jt}$')
ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
complex_cylinder(0,2*np.pi,1,ax)
ax.set_zlabel('$imag(x(t))$')
ax.legend()
plt.savefig('FIG/exp_predtoceni.pdf')

# %%
# zmena modulu i predtoceni 
#modře, $1.5 e^{j\frac{\pi}{4}} e^{jx}$ červeně a
#$\frac{1}{2}e^{-j\frac{2\pi}{3}} e^{jx}$ zeleně. 
t = np.arange(0,2*np.pi,0.05)
x = np.exp(1j*t)
x1 = 1.5*np.exp(1j*np.pi/4)*np.exp(1j*t)
x2 = 0.5*np.exp(-1j*2*np.pi/3)*np.exp(1j*t)
plt.figure(figsize=(8,3))
ax = plt.axes(projection="3d")
ax.plot3D(t, np.real(x), np.imag(x),color='b',label='$e^{jt}$')
ax.plot3D(t, np.real(x1), np.imag(x1),color='r',label='$1.5e^{j\pi/4}e^{jt}$')
ax.plot3D(t, np.real(x2), np.imag(x2),color='g',label='$0.5e^{-j2\pi/3}e^{jt}$')
#ax.plot3D(np.zeros(t.shape), np.real(x), np.imag(x),color='k')
ax.legend()
ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
ax.set_zlabel('$imag(x(t))$')
complex_cylinder(0,2*np.pi,1,ax)
complex_cylinder(0,2*np.pi,1.5,ax)
complex_cylinder(0,2*np.pi,0.5,ax)
plt.savefig('FIG/exp_modul_i_predtoceni.pdf')

# %%
# exponenciala s jinou periodou, kladna a zaporna kruhova frekvence ... 
om1 = 2000*np.pi # kruh frekvence
T1 = 2*np.pi / om1 # perioda 
t = np.linspace(0,T1,num=200)
x = np.exp(1j*om1*t)
xm = np.exp(-1j*om1*t)
plt.figure(figsize=(8,3))
ax = plt.axes(projection="3d")
ax.plot3D(t, np.real(x), np.imag(x),color='b',label='$e^{j\omega_1 t}$')
ax.plot3D(t, np.real(xm), np.imag(xm),color='r',label='$e^{-j\omega_1 t}$')
ax.legend()
ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
ax.set_zlabel('$imag(x(t))$')
complex_cylinder(0,T1,1,ax)
plt.savefig('FIG/exp_perioda_plus_minus.pdf')

# %%
# rozklad cos do dvou komplexnich exp ... 
plt.figure(figsize=(8,5))
ax = plt.axes(projection="3d")
t = np.linspace(0,T1,num=200)

xplus = 5/2*np.exp(1j*om1*t)
xminus = 5/2*np.exp(-1j*om1*t)
ax.plot3D(t, np.real(xplus), np.imag(xplus))
ax.plot3D(t, np.real(xminus), np.imag(xminus))
complex_cylinder(0,T1,2.5,ax)

x = 5*np.cos(om1*t)
aux1 = np.pad(t, (1,1), 'constant', constant_values=(0,np.max(t))) 
aux2 = np.pad(x, (1,1), 'constant', constant_values=(0,0))
aux3 = np.pad(np.zeros(t.shape), (1,1), 'constant', constant_values=(0,0))
verts = [list(zip(aux1,aux2,aux3))]
cos2d = mplot3d.art3d.Poly3DCollection(verts, alpha=0.5, linewidth=1)
cos2d.set_facecolor((1, 0, 0, 0.2))   # 0.2 is alpha
ax.add_collection3d(cos2d)

ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_zlim3d(-5,5)
ax.set_ylim3d(-5,5)

ax.set_yticks([-5, 0, 5])
ax.set_zticks([-5, 0, 5])
#ax.set_xticks([0, 0.01, 0.02])
ax.set_zlabel('$imag(x(t))$')
ax.view_init(elev=45, azim=-40)

plt.savefig('FIG/cosomegat.pdf')

# %%
# rozklad cos s pocatecni fazi do dvou komplexnich exp ... 
om1 = 100*np.pi # kruh frekvence
T1 = 2*np.pi / om1 # perioda 
t = np.linspace(0,T1,num=200)
plt.figure(figsize=(8,5))

ax = plt.axes(projection="3d")
t = np.linspace(0,T1,num=200)
xplus = 5/2*np.exp(-1j*np.pi/4)*np.exp(1j*om1*t)
xminus = 5/2*np.exp(1j*np.pi/4)*np.exp(-1j*om1*t)
ax.plot3D(t, np.real(xplus), np.imag(xplus))
ax.plot3D(t, np.real(xminus), np.imag(xminus))
complex_cylinder(0,T1,2.5,ax)

x = 5*np.cos(om1*t-np.pi/4)
aux1 = np.pad(t, (1,1), 'constant', constant_values=(0,np.max(t))) 
aux2 = np.pad(x, (1,1), 'constant', constant_values=(0,0))
aux3 = np.pad(np.zeros(t.shape), (1,1), 'constant', constant_values=(0,0))
verts = [list(zip(aux1,aux2,aux3))]
cos2d = mplot3d.art3d.Poly3DCollection(verts, alpha=0.5, linewidth=1)
cos2d.set_facecolor((1, 0, 0, 0.2))   # 0.2 is alpha
ax.add_collection3d(cos2d)

ax.set_xlabel('$t$')
ax.set_ylabel('$real(x(t))$')
ax.set_zlim3d(-5,5)
ax.set_ylim3d(-5,5)

ax.set_xticks([0, 0.01, 0.02])
ax.set_yticks([-5, 0, 5])
ax.set_zticks([-5, 0, 5])
ax.set_zlabel('$imag(x(t))$')
ax.view_init(elev=45, azim=-40)

plt.savefig('FIG/cosphi.pdf')

# %%
c1 = 5/2*np.exp(-1j*np.pi/4)
cm1 = 5/2*np.exp(1j*np.pi/4)
C = np.real(c1 + cm1) # melo by byt realne, ale kvuli num. nepresnostem neni, tak to udelame...
plt.figure(figsize=(3,3))
plt.gca().set_ylim(-3.5,3.5)
plt.gca().set_xlim(-0.5,5.5)
plt.gca().scatter(np.real(c1),np.imag(c1),color='r')
plt.gca().scatter(np.real(cm1),np.imag(cm1),color='b')
plt.gca().text(np.real(c1)+0.3,np.imag(c1),'$c_1$')
plt.gca().text(np.real(cm1)+0.3,np.imag(cm1),'$c_{-1}$')
plt.gca().arrow(0, 0, np.real(c1),np.imag(c1), head_width=0.1, head_length=0.3, length_includes_head=True, fc='black', ec='black')
plt.gca().arrow(0, 0, np.real(cm1),np.imag(cm1), head_width=0.1, head_length=0.3, length_includes_head=True, fc='black', ec='black')
plt.gca().arrow(0,0,C,0,head_width=0.1, head_length=0.3, linewidth=3, length_includes_head=True, fc='black', ec='black')
plt.gca().text(C+0.1,0.1,'$c_1 + c_{-1}$')
plt.gca().scatter(C,0,color='k')
plt.gca().grid()
plt.gca().set_xlabel('Real')
plt.gca().set_ylabel('Imag')
plt.tight_layout()
plt.savefig('FIG/c1cm1.pdf')

# %%
# diskretni komplexni exponenciala
import mpl_toolkits.mplot3d.art3d as art3d
n = np.arange(0,32)
x1 = np.exp(1j * 2*np.pi/32 * n)
x2 = np.exp(1j * 2*np.pi*2/32 * n)

plt.figure(figsize=(8,4))
ax = plt.axes(projection="3d")
for xi, yi, zi in zip(n, np.real(x1), np.imag(x1)):        
    line=art3d.Line3D(*zip((xi, 0, 0), (xi, yi, zi)), marker='o', markevery=(1, 1))
    ax.add_line(line)
ax.set_xlim3d(0, 32)
ax.set_ylim3d(-1, 1)
ax.set_zlim3d(-1, 1)
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
ax.set_xlabel('$n$')
ax.set_ylabel('$real(x[n])$')
ax.set_zlabel('$imag(x[n])$')
complex_cylinder(0,32,1,ax)

plt.savefig('FIG/dexp32_1.pdf')

# %%
plt.figure(figsize=(8,4))
ax = plt.axes(projection="3d")
for xi, yi, zi in zip(n, np.real(x2), np.imag(x2)):        
    line=art3d.Line3D(*zip((xi, 0, 0), (xi, yi, zi)), marker='o', markevery=(1, 1))
    ax.add_line(line)
ax.set_xlim3d(0, 32)
ax.set_ylim3d(-1, 1)
ax.set_zlim3d(-1, 1)
ax.set_yticks([-1, 0, 1])
ax.set_zticks([-1, 0, 1])
ax.set_xlabel('$n$')
ax.set_ylabel('$real(x[n])$')
ax.set_zlabel('$imag(x[n])$')
complex_cylinder(0,32,1,ax)

plt.savefig('FIG/dexp32_2.pdf')

# %%
# nasobeni kompl. exponencialy komplexnimi koeficienty 
# diskretni komplexni exponenciala
n = np.arange(0,32)
x1 = np.exp(1j * 2*np.pi/32 * n)
x2 = 5*np.exp(-1j*np.pi/3)*np.exp(1j * 2*np.pi/32 * n)
x3 = 5*np.exp(1j*np.pi/3)*np.exp(1j * 2*np.pi/32 * n)

plt.figure(figsize=(8,4))
ax = plt.axes(projection="3d")
for xi, yi, zi in zip(n, np.real(x2), np.imag(x2)):        
    line=art3d.Line3D(*zip((xi, 0, 0), (xi, yi, zi)), marker='o', markevery=(1, 1),color='r')
    ax.add_line(line)
for xi, yi, zi in zip(n, np.real(x3), np.imag(x3)):        
    line=art3d.Line3D(*zip((xi, 0, 0), (xi, yi, zi)), marker='o', markevery=(1, 1),color='g')
    ax.add_line(line)
ax.set_xlim3d(0, 32)
ax.set_ylim3d(-5, 5)
ax.set_zlim3d(-5, 5)
ax.set_yticks([-5, 0, 5])
ax.set_zticks([-5, 0, 5])
ax.set_xlabel('$n$')
ax.set_ylabel('$real(x[n])$')
ax.set_zlabel('$imag(x[n])$')
complex_cylinder(0,32,5,ax)

plt.savefig('FIG/dexp32_nasobeni.pdf')

# %%
# rozklad disk. cosinusovky na 2 komplexni exponencialy 
n = np.arange(0,32)
x = 5*np.cos(2*np.pi/32 * n - np.pi/3)
xplus = 2.5*np.exp(-1j*np.pi/3)*np.exp(1j * 2*np.pi/32 * n)
xminus = 2.5*np.exp(1j*np.pi/3)*np.exp(1j * 2*np.pi/32 * n)

plt.figure(figsize=(10,6))
ax = plt.axes(projection="3d")
for xi, yi, zi in zip(n, np.real(xplus), np.imag(xplus)):        
    line=art3d.Line3D(*zip((xi, 0, 0), (xi, yi, zi)), marker='o', markevery=(1, 1),color='b')
    ax.add_line(line)
for xi, yi, zi in zip(n, np.real(xminus), np.imag(xminus)):        
    line=art3d.Line3D(*zip((xi, 0, 0), (xi, yi, zi)), marker='o', markevery=(1, 1),color='r')
    ax.add_line(line)
for xi, yi, zi in zip(n, x, np.zeros(n.shape)):        
    line=art3d.Line3D(*zip((xi, 0, 0), (xi, yi, zi)), marker='o', markevery=(1, 1),color='k')
    ax.add_line(line)
complex_cylinder(0,32,2.5,ax)
   
ax.set_xlim3d(0, 32)
ax.set_ylim3d(-5, 5)
ax.set_zlim3d(-5, 5)
ax.set_yticks([-5, 0, 5])
ax.set_zticks([-5, 0, 5])
ax.set_xlabel('$n$')
ax.set_ylabel('$real(x[n])$')
ax.set_zlabel('$imag(x[n])$')

ax.view_init(elev=45, azim=-40)
plt.savefig('FIG/dcos_rozklad.pdf')

# %%
# body v kompexni rovine pro soucet disk. komplexni exponencialy 
for nfig,N in enumerate([2,4,8,16]):
    fig = plt.figure(figsize=(4,4))
    pac = mpatches.Arc([0, 0], 2, 2, angle=0, theta1=0, theta2=360, linestyle='--',color='k')
    n = np.arange(0,N)
    x = np.exp(1j*2*np.pi/N*n)
    fig.gca().set_ylim(-1.1,1.1)
    fig.gca().set_xlim(-1.1,1.1)
    fig.gca().set_yticks([-1, 0, 1])
    fig.gca().set_xticks([-1, 0, 1])

    fig.gca().add_patch(pac)
    fig.gca().set_xlabel('Real')
    fig.gca().set_ylabel('Imag')
    fig.gca().grid()
    for xx in x[0:int(N/2)]:
        fig.gca().scatter(np.real(xx),np.imag(xx),s=50,color='r')
        fig.gca().arrow(0, 0, np.real(xx),np.imag(xx), head_width=0.05, head_length=0.1, length_includes_head=True, fc='r', ec='r')
    for xx in x[int(N/2):N]:
        fig.gca().scatter(np.real(xx),np.imag(xx),s=50,color='b')
        fig.gca().arrow(0, 0, np.real(xx),np.imag(xx), head_width=0.05, head_length=0.1, length_includes_head=True, fc='b', ec='b')
    plt.savefig('FIG/body_'+str(N)+'.pdf')

# %%
# spojita 
fig = plt.figure(figsize=(4,4))
pac = mpatches.Arc([0, 0], 2, 2, angle=0, theta1=0, theta2=180, linewidth=3,color='r')
fig.gca().add_patch(pac)
pac = mpatches.Arc([0, 0], 2, 2, angle=0, theta1=180, theta2=360, linewidth=3,color='b')
fig.gca().add_patch(pac)
fig.gca().set_ylim(-1.1,1.1)
fig.gca().set_xlim(-1.1,1.1)
fig.gca().set_yticks([-1, 0, 1])
fig.gca().set_xticks([-1, 0, 1])
fig.gca().set_xlabel('Real')
fig.gca().set_ylabel('Imag')
x = np.exp(1j*0.85*np.pi)
fig.gca().arrow(0, 0, np.real(x),np.imag(x), head_width=0.05, head_length=0.1, length_includes_head=True, fc='r', ec='r')
fig.gca().arrow(0, 0, np.real(-x),np.imag(-x), head_width=0.05, head_length=0.1, length_includes_head=True, fc='b', ec='b')
fig.gca().grid()
plt.savefig('FIG/int_spoj_cexp.pdf')
